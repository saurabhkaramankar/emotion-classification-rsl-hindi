# %%
# %cd "C:\Users\shaba\Sent_python"
# Out:
# C:\Users\shaba\Sent_python

# %%
# !python run.py --mode="train" --pretrained="fasttext" --head_model="cnn" --dataset="bhaav" --use_dataset=-1 --num_epochs=30 --batch_size=256 --learning_rate=1e-3
# Out:
# Number of samples
# ...
# [TRAIN] 28074
# [VALID] 7019
# [TEST]  14907
#
# Load Embedding ...
# ...
#
#
# Model Architecture
# 2023-05-05 13:48:10.079998: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cudart64_110.dll'; dlerror: cudart64_110.dll not found
# 2023-05-05 13:48:10.080022: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
#
# ...
#  13%|#2        | 15619/124252 [00:02<00:16, 6745.49it/s]
# ...
# TextCNN(
#   (embedding): Embedding(124253, 300)
#   (convs): ModuleList(
#     (0): Conv2d(1, 128, kernel_size=(1, 300), stride=(1, 1))
#     (1): Conv2d(1, 128, kernel_size=(3, 300), stride=(1, 1))
#     (2): Conv2d(1, 128, kernel_size=(5, 300), stride=(1, 1))
#   )
#   (drop): Dropout(p=0.1, inplace=False)
#   (fc): Linear(in_features=384, out_features=2, bias=True)
# )
#
# Start training ...
# ...
#
# epoch  1/30
# -----------
# train - loss: 0.5765 acc: 0.6956
# ...

# %%
# !pwd
# Out:
# /c/Users/shaba

# %%
# !pwd
# Out:
# /c/Users/shaba/Sent_python

# %%
loaded_model = pickle.load(open(filename, 'rb'))
result = loaded_model.score(X_test, Y_test)
print(result)
